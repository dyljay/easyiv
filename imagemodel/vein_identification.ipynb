# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.2/78.2 GB disk)

# %%
# %cd ../datasets
# Out:
# [Errno 2] No such file or directory: '../datasets'
# /content/yolov5

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: valid/
#   inflating: __MACOSX/._valid
#   inflating: valid/.DS_Store
#   inflating: __MACOSX/valid/._.DS_Store
#    creating: valid/images/
#   inflating: __MACOSX/valid/._images
#    creating: valid/labels/
#   inflating: __MACOSX/valid/._labels
#   inflating: valid/images/tannerUS1_mp4-6_jpg.rf.383dfef1040dcd6e596d76243d4eb420.jpg
#   inflating: __MACOSX/valid/images/._tannerUS1_mp4-6_jpg.rf.383dfef1040dcd6e596d76243d4eb420.jpg
#   inflating: valid/images/andreaUS1right_mp4-33_jpg.rf.258246065654e1d9c67631ebae78522c.jpg
#   inflating: __MACOSX/valid/images/._andreaUS1right_mp4-33_jpg.rf.258246065654e1d9c67631ebae78522c.jpg
#   inflating: valid/images/tannerUS2_mp4-13_jpg.rf.0ad37f5ea0781f8b82089130d523a90f.jpg
#   inflating: __MACOSX/valid/images/._tannerUS2_mp4-13_jpg.rf.0ad37f5ea0781f8b82089130d523a90f.jpg
#   inflating: valid/images/tannerUS2_mp4-28_jpg.rf.73419f251ffb02e76f3450bea4df9314.jpg
# ...

# %%
# %cd ../yolov5
# Out:
# [Errno 2] No such file or directory: '../yolov5'
# /content

# %%
# !python train.py --batch 16 --epochs 250 --data vein.yaml --weights yolov5m.pt --freeze 12
# Out:
# train: weights=yolov5m.pt, cfg=, data=vein.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=250, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[12], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights vein_best.pt --source data/images/test1.mp4
# Out:
# detect: weights=['vein_best.pt'], source=data/images/test1.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-140-g1db9533 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# video 1/1 (1/676) /content/yolov5/data/images/test1.mp4: 640x640 (no detections), 27.0ms
# video 1/1 (2/676) /content/yolov5/data/images/test1.mp4: 640x640 (no detections), 27.0ms
# video 1/1 (3/676) /content/yolov5/data/images/test1.mp4: 640x640 (no detections), 27.0ms
# ...

# %%
# !python detect.py --weights yolov5s.pt --source https://www.youtube.com/watch?v=CftLBPI1Ga4
# Out:
# detect: weights=['yolov5s.pt'], source=https://www.youtube.com/watch?v=CftLBPI1Ga4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# requirements: YOLOv5 requirements "pafy" "youtube_dl==2020.12.2" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
